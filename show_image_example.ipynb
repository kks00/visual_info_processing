# %%
import numpy as np
import cv2
from show_image import show_rgb_image, show_images
# %matplotlib inline

# %%
image = np.zeros((400, 400, 3), dtype="uint8")

show_rgb_image(image, "test_image")

# %%
image1 = cv2.imread("./images/chap05/abs_test1.jpg", cv2.IMREAD_COLOR)
image2 = cv2.imread("./images/chap05/abs_test2.jpg", cv2.IMREAD_COLOR)

show_images({"image1": image1, "image2": image2}, 20)
